# %%
# !pip install gym[all]
# Out:
# Requirement already satisfied: gym[all] in c:\users\shank\github.com\shankar-roy\venv\lib\site-packages (0.21.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\shank\github.com\shankar-roy\venv\lib\site-packages (from gym[all]) (2.1.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\shank\github.com\shankar-roy\venv\lib\site-packages (from gym[all]) (1.23.1)
# Requirement already satisfied: lz4>=3.1.0 in c:\users\shank\github.com\shankar-roy\venv\lib\site-packages (from gym[all]) (4.0.1)
# Collecting pyglet>=1.4.0
#   Using cached pyglet-1.5.26-py3-none-any.whl (1.1 MB)
# Collecting box2d-py==2.3.5
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: scipy>=1.4.1 in c:\users\shank\github.com\shankar-roy\venv\lib\site-packages (from gym[all]) (1.8.1)
# Requirement already satisfied: ale-py~=0.7.1 in c:\users\shank\github.com\shankar-roy\venv\lib\site-packages (from gym[all]) (0.7.4)
# Collecting mujoco-py<2.0,>=1.50
#   Using cached mujoco-py-1.50.1.68.tar.gz (120 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: opencv-python>=3. in c:\users\shank\github.com\shankar-roy\venv\lib\site-packages (from gym[all]) (4.6.0.66)
# Requirement already satisfied: importlib-metadata>=4.10.0 in c:\users\shank\github.com\shankar-roy\venv\lib\site-packages (from ale-py~=0.7.1->gym[all]) (4.12.0)
# Requirement already satisfied: importlib-resources in c:\users\shank\github.com\shankar-roy\venv\lib\site-packages (from ale-py~=0.7.1->gym[all]) (5.8.0)
# Collecting glfw>=1.4.0
#   Downloading glfw-2.5.5-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-win_amd64.whl (492 kB)
#      -------------------------------------- 492.9/492.9 kB 4.4 MB/s eta 0:00:00
# Collecting Cython>=0.27.2
#   Using cached Cython-0.29.32-py2.py3-none-any.whl (986 kB)
# Collecting imageio>=2.1.2
#   Downloading imageio-2.21.2-py3-none-any.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 21.5 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.10 in c:\users\shank\github.com\shankar-roy\venv\lib\site-packages (from mujoco-py<2.0,>=1.50->gym[all]) (1.15.1)
# Collecting lockfile>=0.12.2
#   Using cached lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: pycparser in c:\users\shank\github.com\shankar-roy\venv\lib\site-packages (from cffi>=1.10->mujoco-py<2.0,>=1.50->gym[all]) (2.21)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\shank\github.com\shankar-roy\venv\lib\site-packages (from imageio>=2.1.2->mujoco-py<2.0,>=1.50->gym[all]) (9.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\shank\github.com\shankar-roy\venv\lib\site-packages (from importlib-metadata>=4.10.0->ale-py~=0.7.1->gym[all]) (3.8.1)
# Building wheels for collected packages: box2d-py, mujoco-py
#   Building wheel for box2d-py (setup.py): started
#   Building wheel for box2d-py (setup.py): finished with status 'done'
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp38-cp38-win_amd64.whl size=480035 sha256=78cffe8e4ceef72f48df374ac47113ca9cf8af1057e18285d0481247066e41f7
#   Stored in directory: c:\users\shank\appdata\local\pip\cache\wheels\8b\95\16\1dc99ff9a3f316ff245fdb5c9086cd13c35dad630809909075
#   Building wheel for mujoco-py (setup.py): started
#   Building wheel for mujoco-py (setup.py): finished with status 'error'
#   Running setup.py clean for mujoco-py
# Successfully built box2d-py
# Failed to build mujoco-py
# Installing collected packages: pyglet, lockfile, glfw, box2d-py, imageio, Cython, mujoco-py
#   Attempting uninstall: box2d-py
#     Found existing installation: box2d-py 2.3.8
#     Uninstalling box2d-py-2.3.8:
#       Successfully uninstalled box2d-py-2.3.8
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [28 lines of output]
#   running bdist_wheel
#   running build
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\shank\AppData\Local\Temp\pip-install-i25kcbz1\mujoco-py_439aa5f0a36242ed8f1fec8fd06a8a49\setup.py", line 32, in <module>
#       setup(
#     File "C:\Users\shank\github.com\shankar-roy\venv\lib\site-packages\setuptools\__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\shank\AppData\Local\Programs\Python\Python38\lib\distutils\core.py", line 148, in setup
#       dist.run_commands()
#     File "C:\Users\shank\AppData\Local\Programs\Python\Python38\lib\distutils\dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\shank\AppData\Local\Programs\Python\Python38\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\shank\github.com\shankar-roy\venv\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "C:\Users\shank\AppData\Local\Programs\Python\Python38\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\shank\AppData\Local\Programs\Python\Python38\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\shank\AppData\Local\Temp\pip-install-i25kcbz1\mujoco-py_439aa5f0a36242ed8f1fec8fd06a8a49\setup.py", line 28, in run
#       import mujoco_py  # noqa: force build
#     File "C:\Users\shank\AppData\Local\Temp\pip-install-i25kcbz1\mujoco-py_439aa5f0a36242ed8f1fec8fd06a8a49\mujoco_py\__init__.py", line 3, in <module>
#       from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#     File "C:\Users\shank\AppData\Local\Temp\pip-install-i25kcbz1\mujoco-py_439aa5f0a36242ed8f1fec8fd06a8a49\mujoco_py\builder.py", line 17, in <module>
#       from Cython.Build import cythonize
#   ModuleNotFoundError: No module named 'Cython'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for mujoco-py
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\shank\\github.com\\shankar-roy\\venv\\Lib\\site-packages\\~ox2d\\_Box2D.cp38-win_amd64.pyd'
# Check the permissions.

# %%
# !tensorboard --logdir=./tensorboard_log
# Out:
# ^C

# %%
# !pip install pyglet
# Out:
# Requirement already satisfied: pyglet in c:\users\shank\github.com\shankar-roy\venv\lib\site-packages (1.5.26)
# WARNING: Ignoring invalid distribution -ox2d-py (c:\users\shank\github.com\shankar-roy\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ox2d-py (c:\users\shank\github.com\shankar-roy\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ox2d-py (c:\users\shank\github.com\shankar-roy\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ox2d-py (c:\users\shank\github.com\shankar-roy\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ox2d-py (c:\users\shank\github.com\shankar-roy\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -ox2d-py (c:\users\shank\github.com\shankar-roy\venv\lib\site-packages)

# %%
import gym

from stable_baselines3 import A2C
# from stable_baselines3.common.policies import MlpPolicy
from stable_baselines3.common.vec_env import DummyVecEnv

# Create and wrap the environment
env = gym.make('LunarLander-v2')
env = DummyVecEnv([lambda: env])
'''
model = A2C("MlpPolicy", env, ent_coef=0.1, verbose=1, tensorboard_log="./tensorboard_log")
# Train the agent
model.learn(total_timesteps=100000)
# Save the agent
model.save("a2c_lunar")
# del model  # delete trained model to demonstrate loading
'''
# Load the trained agent
model = A2C.load("a2c_lunar")

# Enjoy trained agent
obs = env.reset()
for i in range(1000):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 23>()
#      24 action, _states = model.predict(obs)
#      25 obs, rewards, dones, info = env.step(action)
# ---> 26 env.render()
#
# File ~\github.com\shankar-roy\venv\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:87, in DummyVecEnv.render(self, mode)
#      75 """
#      76 Gym environment rendering. If there are multiple environments then
#      77 they are tiled together in one image via ``BaseVecEnv.render()``.
#    (...)
#      84 :param mode: The rendering type.
#      85 """
#      86 if self.num_envs == 1:
# ---> 87     return self.envs[0].render(mode=mode)
#      88 else:
#      89     return super().render(mode=mode)
#
# File ~\github.com\shankar-roy\venv\lib\site-packages\gym\core.py:295, in Wrapper.render(self, mode, **kwargs)
#     294 def render(self, mode="human", **kwargs):
# --> 295     return self.env.render(mode, **kwargs)
#
# File ~\github.com\shankar-roy\venv\lib\site-packages\gym\envs\box2d\lunar_lander.py:442, in LunarLander.render(self, mode)
#     432     self.viewer.draw_polyline([(x, flagy1), (x, flagy2)], color=(1, 1, 1))
#     433     self.viewer.draw_polygon(
#     434         [
#     435             (x, flagy2),
#    (...)
#     439         color=(0.8, 0.8, 0),
#     440     )
# --> 442 return self.viewer.render(return_rgb_array=mode == "rgb_array")
#
# File ~\github.com\shankar-roy\venv\lib\site-packages\gym\envs\classic_control\rendering.py:145, in Viewer.render(self, return_rgb_array)
#     143     arr = arr.reshape(buffer.height, buffer.width, 4)
#     144     arr = arr[::-1, :, 0:3]
# --> 145 self.window.flip()
#     146 self.onetime_geoms = []
#     147 return arr if return_rgb_array else self.isopen
#
# File ~\github.com\shankar-roy\venv\lib\site-packages\pyglet\window\win32\__init__.py:383, in Win32Window.flip(self)
#     381     if self._always_dwm or self._dwm_composition_enabled():
#     382         if self._interval:
# --> 383             _dwmapi.DwmFlush()
#     385 if self.style in ('overlay', 'transparent'):
#     386     self.update_transparency()
#
# KeyboardInterrupt:

# %%
import gym
from stable_baselines3 import A2C
import os


models_dir = "models/A2C"
logdir = "./tensorboard_log"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(logdir):
    os.makedirs(logdir)

env = gym.make('LunarLander-v2')
env.reset()

model = A2C('MlpPolicy', env, verbose=1, tensorboard_log=logdir)

TIMESTEPS = 10000
iters = 0
for i in range(30):
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name="A2C")
    model.save(f"{models_dir}/{TIMESTEPS*i}")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./tensorboard_log\A2C_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 69.6     |
# |    ep_rew_mean        | -384     |
# | time/                 |          |
# |    fps                | 340      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.939   |
# |    explained_variance | -0.104   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -2.98    |
# |    value_loss         | 73       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 69.9     |
# |    ep_rew_mean        | -423     |
# | time/                 |          |
# |    fps                | 295      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.968   |
# |    explained_variance | -0.00749 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -9.4     |
# |    value_loss         | 103      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 73.9     |
# |    ep_rew_mean        | -412     |
# | time/                 |          |
# |    fps                | 296      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.852   |
# |    explained_variance | -0.0383  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -2.43    |
# |    value_loss         | 5.41     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 76.5     |
# |    ep_rew_mean        | -375     |
# | time/                 |          |
# |    fps                | 306      |
# |    iterations         | 400      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | 5.17e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -13.2    |
# |    value_loss         | 203      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.9     |
# |    ep_rew_mean        | -348     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 500      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.14    |
# |    explained_variance | 0.0232   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -8.69    |
# |    value_loss         | 41.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86.9     |
# |    ep_rew_mean        | -328     |
# | time/                 |          |
# |    fps                | 322      |
# |    iterations         | 600      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -0.00682 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.7      |
# |    value_loss         | 8.7      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 90.9     |
# |    ep_rew_mean        | -296     |
# | time/                 |          |
# |    fps                | 293      |
# |    iterations         | 700      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -0.0164  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 3.23     |
# |    value_loss         | 56.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 96.6     |
# |    ep_rew_mean        | -290     |
# | time/                 |          |
# |    fps                | 304      |
# |    iterations         | 800      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.775   |
# |    explained_variance | 0.0234   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 3.33     |
# |    value_loss         | 30.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 101      |
# |    ep_rew_mean        | -280     |
# | time/                 |          |
# |    fps                | 307      |
# |    iterations         | 900      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.8     |
# |    explained_variance | -0.00488 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -1.18    |
# |    value_loss         | 2.99     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 104      |
# |    ep_rew_mean        | -268     |
# | time/                 |          |
# |    fps                | 317      |
# |    iterations         | 1000     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.791   |
# |    explained_variance | -0.00789 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -2.13    |
# |    value_loss         | 12.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 104      |
# |    ep_rew_mean        | -268     |
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 1100     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | 0.0778   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.189   |
# |    value_loss         | 1.14     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 123      |
# |    ep_rew_mean        | -259     |
# | time/                 |          |
# |    fps                | 312      |
# |    iterations         | 1200     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.38    |
# |    explained_variance | 0.0554   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.999    |
# |    value_loss         | 82.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 125      |
# |    ep_rew_mean        | -253     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 1300     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.995   |
# |    explained_variance | -0.00296 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -6.49    |
# |    value_loss         | 51.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 131      |
# |    ep_rew_mean        | -249     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 1400     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.612   |
# |    explained_variance | 0.0196   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.584   |
# |    value_loss         | 0.716    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 134      |
# |    ep_rew_mean        | -245     |
# | time/                 |          |
# |    fps                | 315      |
# |    iterations         | 1500     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.71    |
# |    explained_variance | -0.00314 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 2.17     |
# |    value_loss         | 29.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 138      |
# |    ep_rew_mean        | -239     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 1600     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.505   |
# |    explained_variance | -0.0306  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 12.5     |
# |    value_loss         | 3.19e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 142      |
# |    ep_rew_mean        | -238     |
# | time/                 |          |
# |    fps                | 311      |
# |    iterations         | 1700     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.964   |
# |    explained_variance | 0.0452   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -1.27    |
# |    value_loss         | 4.75     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 146      |
# |    ep_rew_mean        | -233     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 1800     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.724   |
# |    explained_variance | -0.0024  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 6.6      |
# |    value_loss         | 119      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 148      |
# |    ep_rew_mean        | -224     |
# | time/                 |          |
# |    fps                | 313      |
# |    iterations         | 1900     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.722   |
# |    explained_variance | -0.0144  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 1.48     |
# |    value_loss         | 12.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 150      |
# |    ep_rew_mean        | -221     |
# | time/                 |          |
# |    fps                | 312      |
# |    iterations         | 2000     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.741   |
# |    explained_variance | -0.00577 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 1.16     |
# |    value_loss         | 35.6     |
# ------------------------------------
# Logging to ./tensorboard_log\A2C_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 154      |
# |    ep_rew_mean        | -217     |
# | time/                 |          |
# |    fps                | 317      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -0.0169  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -5.11    |
# |    value_loss         | 51.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 159      |
# |    ep_rew_mean        | -216     |
# | time/                 |          |
# |    fps                | 340      |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.762   |
# |    explained_variance | -0.0136  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -5.45    |
# |    value_loss         | 31.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 159      |
# |    ep_rew_mean        | -210     |
# | time/                 |          |
# |    fps                | 359      |
# |    iterations         | 300      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.783   |
# |    explained_variance | -0.00235 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -2.64    |
# |    value_loss         | 18.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 160      |
# |    ep_rew_mean        | -207     |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 400      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.525   |
# |    explained_variance | 0.00189  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.635   |
# |    value_loss         | 20       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 162      |
# |    ep_rew_mean        | -204     |
# | time/                 |          |
# |    fps                | 345      |
# |    iterations         | 500      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.545   |
# |    explained_variance | 0.211    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.0829   |
# |    value_loss         | 0.211    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 169      |
# |    ep_rew_mean        | -199     |
# | time/                 |          |
# |    fps                | 336      |
# |    iterations         | 600      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.661   |
# |    explained_variance | 0.0925   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -4.12    |
# |    value_loss         | 48.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 170      |
# |    ep_rew_mean        | -196     |
# | time/                 |          |
# |    fps                | 346      |
# |    iterations         | 700      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.451   |
# |    explained_variance | -10.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 3.18     |
# |    value_loss         | 26.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 171      |
# |    ep_rew_mean        | -195     |
# | time/                 |          |
# |    fps                | 343      |
# |    iterations         | 800      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | 0.662    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.642    |
# |    value_loss         | 0.847    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 181      |
# |    ep_rew_mean        | -190     |
# | time/                 |          |
# |    fps                | 336      |
# |    iterations         | 900      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0.00292  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -1.06    |
# |    value_loss         | 5.51     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 182      |
# |    ep_rew_mean        | -190     |
# | time/                 |          |
# |    fps                | 334      |
# |    iterations         | 1000     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.313   |
# |    explained_variance | -4.39    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -4.47    |
# |    value_loss         | 176      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 183      |
# |    ep_rew_mean        | -190     |
# | time/                 |          |
# |    fps                | 325      |
# |    iterations         | 1100     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.34    |
# |    explained_variance | -0.0269  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0286  |
# |    value_loss         | 0.133    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 190      |
# |    ep_rew_mean        | -180     |
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 1200     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.892   |
# |    explained_variance | 0.017    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 1.75     |
# |    value_loss         | 31.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | -178     |
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 1300     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.599   |
# |    explained_variance | 0.662    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -3.56    |
# |    value_loss         | 109      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 190      |
# |    ep_rew_mean        | -178     |
# | time/                 |          |
# |    fps                | 327      |
# |    iterations         | 1400     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.598   |
# |    explained_variance | -0.0406  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -3.7     |
# |    value_loss         | 48       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 190      |
# |    ep_rew_mean        | -176     |
# | time/                 |          |
# |    fps                | 328      |
# |    iterations         | 1500     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.638   |
# |    explained_variance | 0.216    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 1.04     |
# |    value_loss         | 127      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 192      |
# |    ep_rew_mean        | -170     |
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 1600     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.669   |
# |    explained_variance | -0.00499 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 2.42     |
# |    value_loss         | 69.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 194      |
# |    ep_rew_mean        | -169     |
# | time/                 |          |
# |    fps                | 333      |
# |    iterations         | 1700     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.854   |
# |    explained_variance | 0.189    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 3.78     |
# |    value_loss         | 55.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 196      |
# |    ep_rew_mean        | -169     |
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 1800     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.553   |
# |    explained_variance | -0.015   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 1.85     |
# |    value_loss         | 84.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 198      |
# |    ep_rew_mean        | -169     |
# | time/                 |          |
# |    fps                | 329      |
# |    iterations         | 1900     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.587   |
# |    explained_variance | 0.705    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 2.2      |
# |    value_loss         | 13.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 199      |
# |    ep_rew_mean        | -168     |
# | time/                 |          |
# |    fps                | 328      |
# |    iterations         | 2000     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.539   |
# |    explained_variance | 0.511    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 2.15     |
# |    value_loss         | 13       |
# ------------------------------------
# Logging to ./tensorboard_log\A2C_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 203      |
# |    ep_rew_mean        | -165     |
# | time/                 |          |
# |    fps                | 284      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.656   |
# |    explained_variance | -0.0587  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 3.32     |
# |    value_loss         | 43.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 207      |
# |    ep_rew_mean        | -160     |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 200      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.0794  |
# |    explained_variance | 0.078    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.0598   |
# |    value_loss         | 75.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 211      |
# |    ep_rew_mean        | -153     |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 300      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.863   |
# |    explained_variance | 0.504    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.49     |
# |    value_loss         | 0.523    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | -146     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.946   |
# |    explained_variance | -12.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.303    |
# |    value_loss         | 0.578    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 218      |
# |    ep_rew_mean        | -138     |
# | time/                 |          |
# |    fps                | 290      |
# |    iterations         | 500      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -0.0466  |
# |    explained_variance | -23.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.0351  |
# |    value_loss         | 18.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 221      |
# |    ep_rew_mean        | -127     |
# | time/                 |          |
# |    fps                | 299      |
# |    iterations         | 600      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.705   |
# |    explained_variance | 0.036    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -2.26    |
# |    value_loss         | 18       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | -121     |
# | time/                 |          |
# |    fps                | 306      |
# |    iterations         | 700      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.663   |
# |    explained_variance | 0.268    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -5.44    |
# |    value_loss         | 70.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 228      |
# |    ep_rew_mean        | -114     |
# | time/                 |          |
# |    fps                | 309      |
# |    iterations         | 800      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.0716  |
# |    explained_variance | 0.0514   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.18    |
# |    value_loss         | 301      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 230      |
# |    ep_rew_mean        | -112     |
# | time/                 |          |
# |    fps                | 307      |
# |    iterations         | 900      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.651   |
# |    explained_variance | 0.727    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.0667   |
# |    value_loss         | 0.251    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 235      |
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 310      |
# |    iterations         | 1000     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.571   |
# |    explained_variance | 0.0374   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 2.4      |
# |    value_loss         | 23.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 236      |
# |    ep_rew_mean        | -106     |
# | time/                 |          |
# |    fps                | 311      |
# |    iterations         | 1100     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -0.61    |
# |    explained_variance | -0.516   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 4.19     |
# |    value_loss         | 50.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 239      |
# |    ep_rew_mean        | -105     |
# | time/                 |          |
# |    fps                | 312      |
# |    iterations         | 1200     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.278   |
# |    explained_variance | -0.128   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.752    |
# |    value_loss         | 72.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 245      |
# |    ep_rew_mean        | -102     |
# | time/                 |          |
# |    fps                | 316      |
# |    iterations         | 1300     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -0.665   |
# |    explained_variance | 0.208    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 3.98     |
# |    value_loss         | 37.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 249      |
# |    ep_rew_mean        | -98.3    |
# | time/                 |          |
# |    fps                | 315      |
# |    iterations         | 1400     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -0.486   |
# |    explained_variance | -0.0914  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 2.68     |
# |    value_loss         | 17.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 253      |
# |    ep_rew_mean        | -95.8    |
# | time/                 |          |
# |    fps                | 315      |
# |    iterations         | 1500     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.411   |
# |    explained_variance | -0.0383  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -27.6    |
# |    value_loss         | 4.85e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 257      |
# |    ep_rew_mean        | -95.1    |
# | time/                 |          |
# |    fps                | 312      |
# |    iterations         | 1600     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.947   |
# |    explained_variance | -0.0213  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -2.1     |
# |    value_loss         | 35.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 259      |
# |    ep_rew_mean        | -95.7    |
# | time/                 |          |
# |    fps                | 312      |
# |    iterations         | 1700     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.71    |
# |    explained_variance | 0.0387   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -1.94    |
# |    value_loss         | 6.93     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 260      |
# |    ep_rew_mean        | -95.9    |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 1800     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.607   |
# |    explained_variance | -17      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.289    |
# |    value_loss         | 6.41     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 262      |
# |    ep_rew_mean        | -95.7    |
# | time/                 |          |
# |    fps                | 317      |
# |    iterations         | 1900     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.586   |
# |    explained_variance | 0.0616   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.0378   |
# |    value_loss         | 22.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 266      |
# |    ep_rew_mean        | -93      |
# | time/                 |          |
# |    fps                | 316      |
# |    iterations         | 2000     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.372   |
# |    explained_variance | -0.194   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -9.8     |
# |    value_loss         | 265      |
# ------------------------------------
# Logging to ./tensorboard_log\A2C_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 268      |
# |    ep_rew_mean        | -97.4    |
# | time/                 |          |
# |    fps                | 326      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.783   |
# |    explained_variance | 0.0075   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -8.8     |
# |    value_loss         | 47.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 269      |
# |    ep_rew_mean        | -94.6    |
# | time/                 |          |
# |    fps                | 349      |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | -0.247   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -1.28    |
# |    value_loss         | 5.43     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 273      |
# |    ep_rew_mean        | -95.9    |
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 300      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.854   |
# |    explained_variance | 0.141    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.725    |
# |    value_loss         | 7.88     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 276      |
# |    ep_rew_mean        | -95.4    |
# | time/                 |          |
# |    fps                | 300      |
# |    iterations         | 400      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.391   |
# |    explained_variance | -6.06    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 2.9      |
# |    value_loss         | 14.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 278      |
# |    ep_rew_mean        | -95.2    |
# | time/                 |          |
# |    fps                | 300      |
# |    iterations         | 500      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.338   |
# |    explained_variance | 0.00164  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -5.25    |
# |    value_loss         | 45.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 282      |
# |    ep_rew_mean        | -90.8    |
# | time/                 |          |
# |    fps                | 296      |
# |    iterations         | 600      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.506   |
# |    explained_variance | -0.00339 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.399   |
# |    value_loss         | 10.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 276      |
# |    ep_rew_mean        | -90.3    |
# | time/                 |          |
# |    fps                | 301      |
# |    iterations         | 700      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.574   |
# |    explained_variance | -4.39    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -7.07    |
# |    value_loss         | 68       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 277      |
# |    ep_rew_mean        | -86.2    |
# | time/                 |          |
# |    fps                | 301      |
# |    iterations         | 800      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.65    |
# |    explained_variance | -0.00063 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 4.24     |
# |    value_loss         | 88.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 275      |
# |    ep_rew_mean        | -86      |
# | time/                 |          |
# |    fps                | 302      |
# |    iterations         | 900      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.394   |
# |    explained_variance | -13.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -14.9    |
# |    value_loss         | 184      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 277      |
# |    ep_rew_mean        | -87.6    |
# | time/                 |          |
# |    fps                | 297      |
# |    iterations         | 1000     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.131   |
# |    explained_variance | 0.778    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -0.0971  |
# |    value_loss         | 19       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 281      |
# |    ep_rew_mean        | -82.9    |
# | time/                 |          |
# |    fps                | 302      |
# |    iterations         | 1100     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -0.181   |
# |    explained_variance | -28.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.427   |
# |    value_loss         | 137      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 280      |
# |    ep_rew_mean        | -83.2    |
# | time/                 |          |
# |    fps                | 302      |
# |    iterations         | 1200     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.337   |
# |    explained_variance | 0.132    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | -6.41    |
# |    value_loss         | 132      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 278      |
# |    ep_rew_mean        | -83.3    |
# | time/                 |          |
# |    fps                | 299      |
# |    iterations         | 1300     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.0127  |
# |    explained_variance | 0.908    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | -0.00245 |
# |    value_loss         | 4.23     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 278      |
# |    ep_rew_mean        | -85.4    |
# | time/                 |          |
# |    fps                | 302      |
# |    iterations         | 1400     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.45    |
# |    explained_variance | -0.227   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | 0.701    |
# |    value_loss         | 37.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 277      |
# |    ep_rew_mean        | -83.1    |
# | time/                 |          |
# |    fps                | 308      |
# |    iterations         | 1500     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.961   |
# |    explained_variance | 0.0456   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | -0.563   |
# |    value_loss         | 0.587    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 276      |
# |    ep_rew_mean        | -82.6    |
# | time/                 |          |
# |    fps                | 312      |
# |    iterations         | 1600     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.531   |
# |    explained_variance | 0.0825   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | 0.304    |
# ...
# |    explained_variance | 0.659    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57499    |
# |    policy_loss        | 0.29     |
# |    value_loss         | 0.982    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 688      |
# |    ep_rew_mean        | -50      |
# | time/                 |          |
# |    fps                | 220      |
# |    iterations         | 1600     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 288000   |
# | train/                |          |
# |    entropy_loss       | -0.514   |
# |    explained_variance | 0.956    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57599    |
# |    policy_loss        | -0.24    |
# |    value_loss         | 0.262    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 688      |
# |    ep_rew_mean        | -50      |
# | time/                 |          |
# |    fps                | 223      |
# |    iterations         | 1700     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 288500   |
# | train/                |          |
# |    entropy_loss       | -0.542   |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57699    |
# |    policy_loss        | 0.0309   |
# |    value_loss         | 0.0288   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 693      |
# |    ep_rew_mean        | -52.3    |
# | time/                 |          |
# |    fps                | 222      |
# |    iterations         | 1800     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 289000   |
# | train/                |          |
# |    entropy_loss       | -0.362   |
# |    explained_variance | 0.61     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57799    |
# |    policy_loss        | -0.844   |
# |    value_loss         | 5.24     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 693      |
# |    ep_rew_mean        | -52.3    |
# | time/                 |          |
# |    fps                | 225      |
# |    iterations         | 1900     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 289500   |
# | train/                |          |
# |    entropy_loss       | -0.337   |
# |    explained_variance | 0.309    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57899    |
# |    policy_loss        | -0.0673  |
# |    value_loss         | 0.63     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 693      |
# |    ep_rew_mean        | -52.3    |
# | time/                 |          |
# |    fps                | 222      |
# |    iterations         | 2000     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 290000   |
# | train/                |          |
# |    entropy_loss       | -0.435   |
# |    explained_variance | 0.811    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 57999    |
# |    policy_loss        | 0.228    |
# |    value_loss         | 1.81     |
# ------------------------------------
# Logging to ./tensorboard_log\A2C_0
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 700      |
# |    ep_rew_mean        | -52      |
# | time/                 |          |
# |    fps                | 181      |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 290500   |
# | train/                |          |
# |    entropy_loss       | -0.23    |
# |    explained_variance | 0.652    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58099    |
# |    policy_loss        | -0.0556  |
# |    value_loss         | 0.956    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 700      |
# |    ep_rew_mean        | -52      |
# | time/                 |          |
# |    fps                | 214      |
# |    iterations         | 200      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 291000   |
# | train/                |          |
# |    entropy_loss       | -0.562   |
# |    explained_variance | 0.959    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58199    |
# |    policy_loss        | 0.101    |
# |    value_loss         | 0.0539   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 705      |
# |    ep_rew_mean        | -54.9    |
# | time/                 |          |
# |    fps                | 227      |
# |    iterations         | 300      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 291500   |
# | train/                |          |
# |    entropy_loss       | -0.351   |
# |    explained_variance | 0.224    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58299    |
# |    policy_loss        | 0.599    |
# |    value_loss         | 6.47     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 703      |
# |    ep_rew_mean        | -58.1    |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 400      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 292000   |
# | train/                |          |
# |    entropy_loss       | -0.441   |
# |    explained_variance | 0.447    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58399    |
# |    policy_loss        | -0.876   |
# |    value_loss         | 5.3      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 703      |
# |    ep_rew_mean        | -58.1    |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 500      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 292500   |
# | train/                |          |
# |    entropy_loss       | -0.109   |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58499    |
# |    policy_loss        | -0.00164 |
# |    value_loss         | 0.134    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 709      |
# |    ep_rew_mean        | -60.8    |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 600      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 293000   |
# | train/                |          |
# |    entropy_loss       | -0.261   |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58599    |
# |    policy_loss        | -0.0626  |
# |    value_loss         | 0.0175   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 709      |
# |    ep_rew_mean        | -60.8    |
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 700      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 293500   |
# | train/                |          |
# |    entropy_loss       | -0.565   |
# |    explained_variance | -0.464   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58699    |
# |    policy_loss        | -0.0247  |
# |    value_loss         | 1.04     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 717      |
# |    ep_rew_mean        | -60.9    |
# | time/                 |          |
# |    fps                | 241      |
# |    iterations         | 800      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 294000   |
# | train/                |          |
# |    entropy_loss       | -0.143   |
# |    explained_variance | 0.307    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58799    |
# |    policy_loss        | 0.0332   |
# |    value_loss         | 1.15     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 720      |
# |    ep_rew_mean        | -61.3    |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 900      |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 294500   |
# | train/                |          |
# |    entropy_loss       | -0.528   |
# |    explained_variance | 0.692    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58899    |
# |    policy_loss        | -0.143   |
# |    value_loss         | 0.145    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 720      |
# |    ep_rew_mean        | -61.3    |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 1000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 295000   |
# | train/                |          |
# |    entropy_loss       | -0.639   |
# |    explained_variance | 0.878    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 58999    |
# |    policy_loss        | 0.242    |
# |    value_loss         | 0.185    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 726      |
# |    ep_rew_mean        | -63.3    |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 1100     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 295500   |
# | train/                |          |
# |    entropy_loss       | -0.453   |
# |    explained_variance | 0.789    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59099    |
# |    policy_loss        | -0.895   |
# |    value_loss         | 1.07     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 726      |
# |    ep_rew_mean        | -63      |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 1200     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 296000   |
# | train/                |          |
# |    entropy_loss       | -0.462   |
# |    explained_variance | 0.758    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59199    |
# |    policy_loss        | -0.152   |
# |    value_loss         | 1.03     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 726      |
# |    ep_rew_mean        | -63      |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1300     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 296500   |
# | train/                |          |
# |    entropy_loss       | -0.468   |
# |    explained_variance | -0.824   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59299    |
# |    policy_loss        | -0.23    |
# |    value_loss         | 3.58     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 733      |
# |    ep_rew_mean        | -62.6    |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 1400     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 297000   |
# | train/                |          |
# |    entropy_loss       | -0.222   |
# |    explained_variance | -0.304   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59399    |
# |    policy_loss        | 1.56     |
# |    value_loss         | 19.2     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 733       |
# |    ep_rew_mean        | -62.6     |
# | time/                 |           |
# |    fps                | 251       |
# |    iterations         | 1500      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 297500    |
# | train/                |           |
# |    entropy_loss       | -4.56e-09 |
# |    explained_variance | 0.447     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 59499     |
# |    policy_loss        | -0        |
# |    value_loss         | 0.407     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 737      |
# |    ep_rew_mean        | -63.2    |
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 1600     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 298000   |
# | train/                |          |
# |    entropy_loss       | -0.396   |
# |    explained_variance | 0.905    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59599    |
# |    policy_loss        | -0.318   |
# |    value_loss         | 0.422    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 737      |
# |    ep_rew_mean        | -63.2    |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 1700     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 298500   |
# | train/                |          |
# |    entropy_loss       | -0.387   |
# |    explained_variance | 0.76     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59699    |
# |    policy_loss        | 0.0683   |
# |    value_loss         | 0.218    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 745      |
# |    ep_rew_mean        | -62.6    |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 1800     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 299000   |
# | train/                |          |
# |    entropy_loss       | -0.289   |
# |    explained_variance | 0.974    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59799    |
# |    policy_loss        | 0.0926   |
# |    value_loss         | 0.106    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 750      |
# |    ep_rew_mean        | -60.7    |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 1900     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 299500   |
# | train/                |          |
# |    entropy_loss       | -0.393   |
# |    explained_variance | 0.639    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59899    |
# |    policy_loss        | 0.457    |
# |    value_loss         | 0.89     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 750      |
# |    ep_rew_mean        | -60.7    |
# | time/                 |          |
# |    fps                | 239      |
# |    iterations         | 2000     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 300000   |
# | train/                |          |
# |    entropy_loss       | -0.7     |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 59999    |
# |    policy_loss        | -0.724   |
# |    value_loss         | 0.341    |
# ------------------------------------

# %%
import gym
from stable_baselines3 import PPO
import os


models_dir = "models/PPO"
logdir = "./tensorboard_log"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(logdir):
    os.makedirs(logdir)

env = gym.make('LunarLander-v2')
env.reset()

model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=logdir)

TIMESTEPS = 10000
iters = 0
for i in range(30):
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name="PPO")
    model.save(f"{models_dir}/{TIMESTEPS*i}")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.9     |
# |    ep_rew_mean     | -165     |
# | time/              |          |
# |    fps             | 542      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.8         |
# |    ep_rew_mean          | -174         |
# | time/                   |              |
# |    fps                  | 421          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0045548766 |
# |    clip_fraction        | 0.00435      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00742      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 434          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 1.17e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 95.3       |
# |    ep_rew_mean          | -171       |
# | time/                   |            |
# |    fps                  | 404        |
# |    iterations           | 3          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00830069 |
# |    clip_fraction        | 0.0291     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | -0.00723   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 653        |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00866   |
# |    value_loss           | 1.2e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98          |
# |    ep_rew_mean          | -171        |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 4           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007809565 |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.0249     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 485         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00761    |
# |    value_loss           | 877         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -165        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 5           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008149561 |
# |    clip_fraction        | 0.0438      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.000384    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 287         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00571    |
# |    value_loss           | 909         |
# -----------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -164     |
# | time/              |          |
# |    fps             | 585      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 12288    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 106          |
# |    ep_rew_mean          | -143         |
# | time/                   |              |
# |    fps                  | 461          |
# |    iterations           | 2            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0044074445 |
# |    clip_fraction        | 0.00273      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.0478      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 401          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00406     |
# |    value_loss           | 613          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | -129        |
# | time/                   |             |
# |    fps                  | 424         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014547782 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.000148   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 119         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 311         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 119        |
# |    ep_rew_mean          | -127       |
# | time/                   |            |
# |    fps                  | 391        |
# |    iterations           | 4          |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00930167 |
# |    clip_fraction        | 0.0582     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | -0.000143  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 93.9       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00808   |
# |    value_loss           | 287        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 131          |
# |    ep_rew_mean          | -120         |
# | time/                   |              |
# |    fps                  | 373          |
# |    iterations           | 5            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0037840838 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.00683      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 157          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00456     |
# |    value_loss           | 441          |
# ------------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    fps             | 518      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 22528    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008366188 |
# |    clip_fraction        | 0.0127      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | -0.00775    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 162         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00422    |
# |    value_loss           | 320         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 157         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 3           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008550753 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | -0.241      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 190         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0059     |
# |    value_loss           | 493         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 170       |
# |    ep_rew_mean          | -114      |
# | time/                   |           |
# |    fps                  | 375       |
# |    iterations           | 4         |
# |    time_elapsed         | 21        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0095889 |
# |    clip_fraction        | 0.0159    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.18     |
# |    explained_variance   | 0.34      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 144       |
# |    n_updates            | 130       |
# |    policy_gradient_loss | -0.00389  |
# |    value_loss           | 213       |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 186          |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 357          |
# |    iterations           | 5            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0044795624 |
# |    clip_fraction        | 0.00435      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.126        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 212          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00425     |
# |    value_loss           | 487          |
# ------------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    fps             | 530      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 32768    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 206          |
# |    ep_rew_mean          | -112         |
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0035678311 |
# |    clip_fraction        | 0.00596      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.203        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 205          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00399     |
# |    value_loss           | 377          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 217          |
# |    ep_rew_mean          | -110         |
# | time/                   |              |
# |    fps                  | 373          |
# |    iterations           | 3            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0068823257 |
# |    clip_fraction        | 0.0618       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.285        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 111          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00653     |
# |    value_loss           | 204          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 234        |
# |    ep_rew_mean          | -111       |
# | time/                   |            |
# |    fps                  | 344        |
# |    iterations           | 4          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.01236077 |
# |    clip_fraction        | 0.0989     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 0.473      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 22.2       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.00768   |
# |    value_loss           | 107        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 5           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010228548 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 135         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 173         |
# -----------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 267      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    fps             | 414      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 43008    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 283         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 2           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008370716 |
# |    clip_fraction        | 0.0358      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 77.2        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00642    |
# |    value_loss           | 174         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 278          |
# |    ep_rew_mean          | -100         |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 3            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0057427064 |
# |    clip_fraction        | 0.0413       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.5          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.8         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0052      |
# |    value_loss           | 116          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 288          |
# |    ep_rew_mean          | -98.7        |
# | time/                   |              |
# |    fps                  | 265          |
# |    iterations           | 4            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0034431713 |
# |    clip_fraction        | 0.0188       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.373        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 56.6         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0051      |
# |    value_loss           | 145          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 302         |
# |    ep_rew_mean          | -98.1       |
# | time/                   |             |
# |    fps                  | 271         |
# |    iterations           | 5           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009935103 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00535    |
# |    value_loss           | 51.7        |
# -----------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 317      |
# |    ep_rew_mean     | -97.2    |
# | time/              |          |
# |    fps             | 421      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 53248    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -97.3       |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007328163 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 91.9        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00657    |
# |    value_loss           | 180         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 347        |
# |    ep_rew_mean          | -96.3      |
# | time/                   |            |
# |    fps                  | 318        |
# |    iterations           | 3          |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.00780602 |
# |    clip_fraction        | 0.0687     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | 0.729      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 29.3       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.00675   |
# |    value_loss           | 96.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 364         |
# |    ep_rew_mean          | -92.8       |
# | time/                   |             |
# |    fps                  | 312         |
# |    iterations           | 4           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008300457 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.4        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00591    |
# |    value_loss           | 48.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 385         |
# |    ep_rew_mean          | -86.8       |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 5           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.005096364 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.4         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00589    |
# |    value_loss           | 23          |
# -----------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 396      |
# |    ep_rew_mean     | -84.5    |
# | time/              |          |
# |    fps             | 336      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 63488    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 411         |
# |    ep_rew_mean          | -79.7       |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008349094 |
# |    clip_fraction        | 0.0519      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.946      |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.6        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00627    |
# |    value_loss           | 35.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 432         |
# |    ep_rew_mean          | -77.3       |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.014993025 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.87        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00581    |
# |    value_loss           | 20.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 449         |
# |    ep_rew_mean          | -73         |
# | time/                   |             |
# |    fps                  | 265         |
# |    iterations           | 4           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.010556455 |
# |    clip_fraction        | 0.0845      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.9        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00897    |
# |    value_loss           | 41.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 469         |
# |    ep_rew_mean          | -69.1       |
# | time/                   |             |
# |    fps                  | 262         |
# |    iterations           | 5           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.014236648 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.964      |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.94        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00723    |
# |    value_loss           | 19          |
# -----------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 476      |
# |    ep_rew_mean     | -64.7    |
# | time/              |          |
# |    fps             | 375      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 73728    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 489         |
# |    ep_rew_mean          | -59.7       |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.010410274 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.797      |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.31        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00614    |
# |    value_loss           | 44.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 502         |
# |    ep_rew_mean          | -51.1       |
# | time/                   |             |
# |    fps                  | 311         |
# |    iterations           | 3           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.010595137 |
# |    clip_fraction        | 0.079       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.1        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00666    |
# |    value_loss           | 73          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 510         |
# |    ep_rew_mean          | -33.3       |
# | time/                   |             |
# |    fps                  | 309         |
# |    iterations           | 4           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.019732207 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.872      |
# |    explained_variance   | 0.501       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.8        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00804    |
# |    value_loss           | 94          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 522         |
# |    ep_rew_mean          | -28.5       |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 5           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007977836 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.761      |
# |    explained_variance   | 0.268       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.6        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00359    |
# |    value_loss           | 218         |
# -----------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 527      |
# |    ep_rew_mean     | -15.4    |
# | time/              |          |
# |    fps             | 444      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 83968    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 535          |
# |    ep_rew_mean          | -6.32        |
# | time/                   |              |
# |    fps                  | 362          |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0063477233 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.924       |
# |    explained_variance   | 0.309        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.6         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00382     |
# |    value_loss           | 247          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 543         |
# |    ep_rew_mean          | 5.44        |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.003707205 |
# |    clip_fraction        | 0.0221      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.747      |
# |    explained_variance   | 0.481       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 129         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00171    |
# |    value_loss           | 202         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 551         |
# |    ep_rew_mean          | 15.9        |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 4           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.007173666 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 79.7        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00426    |
# |    value_loss           | 219         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 560         |
# |    ep_rew_mean          | 20.3        |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 5           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008104187 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.8        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0045     |
# |    value_loss           | 171         |
# -----------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 560      |
# |    ep_rew_mean     | 29.5     |
# | time/              |          |
# |    fps             | 314      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 94208    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 574          |
# |    ep_rew_mean          | 43.7         |
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 2            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0042920774 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.837       |
# |    explained_variance   | 0.661        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.4         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00371     |
# |    value_loss           | 141          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 575          |
# |    ep_rew_mean          | 55.7         |
# | time/                   |              |
# |    fps                  | 263          |
# |    iterations           | 3            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0055938717 |
# |    clip_fraction        | 0.0785       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.872       |
# |    explained_variance   | 0.534        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.1         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00312     |
# |    value_loss           | 106          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 562          |
# |    ep_rew_mean          | 60.5         |
# | time/                   |              |
# |    fps                  | 277          |
# |    iterations           | 4            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0030470092 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.771       |
# |    explained_variance   | 0.448        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.6         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 187          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 569         |
# |    ep_rew_mean          | 70.6        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 5           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.005251433 |
# |    clip_fraction        | 0.037       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 120         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00723    |
# |    value_loss           | 218         |
# -----------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 576      |
# |    ep_rew_mean     | 80.9     |
# | time/              |          |
# |    fps             | 382      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 104448   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 571          |
# |    ep_rew_mean          | 88           |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 2            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0048097195 |
# |    clip_fraction        | 0.0287       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.743       |
# |    explained_variance   | 0.48         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 68.6         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00349     |
# |    value_loss           | 117          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 568         |
# |    ep_rew_mean          | 98.6        |
# | time/                   |             |
# |    fps                  | 319         |
# |    iterations           | 3           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.009961862 |
# |    clip_fraction        | 0.0898      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.931      |
# |    explained_variance   | 0.517       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.9        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00499    |
# |    value_loss           | 90.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 568         |
# |    ep_rew_mean          | 114         |
# | time/                   |             |
# |    fps                  | 315         |
# |    iterations           | 4           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.004265799 |
# |    clip_fraction        | 0.0438      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.757      |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.3        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00383    |
# |    value_loss           | 127         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 567         |
# |    ep_rew_mean          | 120         |
# | time/                   |             |
# |    fps                  | 313         |
# |    iterations           | 5           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.009305386 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.916      |
# |    explained_variance   | 0.603       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.4        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 130         |
# -----------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 533      |
# |    ep_rew_mean     | 128      |
# | time/              |          |
# |    fps             | 467      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 114688   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 511          |
# |    ep_rew_mean          | 135          |
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 2            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0063121775 |
# |    clip_fraction        | 0.0769       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.894       |
# |    explained_variance   | 0.533        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 88.6         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00336     |
# |    value_loss           | 199          |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 483       |
# |    ep_rew_mean          | 141       |
# | time/                   |           |
# |    fps                  | 352       |
# |    iterations           | 3         |
# |    time_elapsed         | 17        |
# |    total_timesteps      | 118784    |
# | train/                  |           |
# |    approx_kl            | 0.0108673 |
# |    clip_fraction        | 0.0794    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.812    |
# |    explained_variance   | 0.523     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 109       |
# |    n_updates            | 570       |
# |    policy_gradient_loss | -0.00557  |
# |    value_loss           | 189       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 460         |
# |    ep_rew_mean          | 143         |
# | time/                   |             |
# |    fps                  | 349         |
# |    iterations           | 4           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.004794783 |
# |    clip_fraction        | 0.0221      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.9        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00208    |
# |    value_loss           | 121         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 448          |
# |    ep_rew_mean          | 149          |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 5            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0034670667 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.818       |
# |    explained_variance   | 0.302        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 145          |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00365     |
# |    value_loss           | 276          |
# ------------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 442      |
# |    ep_rew_mean     | 158      |
# | time/              |          |
# |    fps             | 482      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 124928   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 440          |
# |    ep_rew_mean          | 163          |
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 2            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0061322153 |
# |    clip_fraction        | 0.0683       |
# ...
# |    n_updates            | 1290        |
# |    policy_gradient_loss | -0.00909    |
# |    value_loss           | 46.2        |
# -----------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 327      |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    fps             | 513      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 268288   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 316         |
# |    ep_rew_mean          | 195         |
# | time/                   |             |
# |    fps                  | 418         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.003439968 |
# |    clip_fraction        | 0.0518      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.679      |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.1        |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.00267    |
# |    value_loss           | 76.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 306          |
# |    ep_rew_mean          | 194          |
# | time/                   |              |
# |    fps                  | 400          |
# |    iterations           | 3            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 272384       |
# | train/                  |              |
# |    approx_kl            | 0.0029364019 |
# |    clip_fraction        | 0.0485       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.775       |
# |    explained_variance   | 0.614        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.6         |
# |    n_updates            | 1320         |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 207          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 299          |
# |    ep_rew_mean          | 199          |
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 4            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 274432       |
# | train/                  |              |
# |    approx_kl            | 0.0028870744 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.715       |
# |    explained_variance   | 0.565        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.2         |
# |    n_updates            | 1330         |
# |    policy_gradient_loss | -0.00246     |
# |    value_loss           | 198          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 304         |
# |    ep_rew_mean          | 199         |
# | time/                   |             |
# |    fps                  | 380         |
# |    iterations           | 5           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 276480      |
# | train/                  |             |
# |    approx_kl            | 0.008743068 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.708      |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 1340        |
# |    policy_gradient_loss | -0.00465    |
# |    value_loss           | 39.7        |
# -----------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 304      |
# |    ep_rew_mean     | 204      |
# | time/              |          |
# |    fps             | 507      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 278528   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 311          |
# |    ep_rew_mean          | 212          |
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 280576       |
# | train/                  |              |
# |    approx_kl            | 0.0052015656 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.73        |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62           |
# |    n_updates            | 1360         |
# |    policy_gradient_loss | -0.00317     |
# |    value_loss           | 86.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 313          |
# |    ep_rew_mean          | 218          |
# | time/                   |              |
# |    fps                  | 344          |
# |    iterations           | 3            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 282624       |
# | train/                  |              |
# |    approx_kl            | 0.0070037385 |
# |    clip_fraction        | 0.0647       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.605       |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15           |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 22           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 317          |
# |    ep_rew_mean          | 216          |
# | time/                   |              |
# |    fps                  | 344          |
# |    iterations           | 4            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 284672       |
# | train/                  |              |
# |    approx_kl            | 0.0061679548 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.685       |
# |    explained_variance   | 0.643        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.4         |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 90           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 329         |
# |    ep_rew_mean          | 211         |
# | time/                   |             |
# |    fps                  | 344         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.011868998 |
# |    clip_fraction        | 0.0998      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.668      |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.1        |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 81.5        |
# -----------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 337      |
# |    ep_rew_mean     | 212      |
# | time/              |          |
# |    fps             | 471      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 288768   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 336         |
# |    ep_rew_mean          | 209         |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.008714277 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.731      |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.00104    |
# |    value_loss           | 35.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 336         |
# |    ep_rew_mean          | 209         |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 3           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.004335014 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.761      |
# |    explained_variance   | 0.775       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 96.6        |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.00356    |
# |    value_loss           | 107         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | 217          |
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 4            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0023693494 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.461       |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 64.1         |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | -0.00203     |
# |    value_loss           | 49.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 316          |
# |    ep_rew_mean          | 219          |
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 5            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 296960       |
# | train/                  |              |
# |    approx_kl            | 0.0079736905 |
# |    clip_fraction        | 0.099        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.715       |
# |    explained_variance   | 0.864        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.6         |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.00536     |
# |    value_loss           | 87.6         |
# ------------------------------------------
# Logging to ./tensorboard_log\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 316      |
# |    ep_rew_mean     | 220      |
# | time/              |          |
# |    fps             | 510      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 299008   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 315          |
# |    ep_rew_mean          | 226          |
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 2            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 301056       |
# | train/                  |              |
# |    approx_kl            | 0.0076149204 |
# |    clip_fraction        | 0.0616       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.704       |
# |    explained_variance   | 0.692        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.5         |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | -0.00286     |
# |    value_loss           | 33.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 314         |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.007495563 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.726      |
# |    explained_variance   | 0.603       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.4        |
# |    n_updates            | 1470        |
# |    policy_gradient_loss | -0.0029     |
# |    value_loss           | 98.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 312         |
# |    ep_rew_mean          | 229         |
# | time/                   |             |
# |    fps                  | 319         |
# |    iterations           | 4           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 305152      |
# | train/                  |             |
# |    approx_kl            | 0.004428586 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.688      |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.4        |
# |    n_updates            | 1480        |
# |    policy_gradient_loss | -0.000945   |
# |    value_loss           | 122         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 305          |
# |    ep_rew_mean          | 229          |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 5            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 307200       |
# | train/                  |              |
# |    approx_kl            | 0.0070075355 |
# |    clip_fraction        | 0.0695       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.702       |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.6         |
# |    n_updates            | 1490         |
# |    policy_gradient_loss | -0.00382     |
# |    value_loss           | 51.3         |
# ------------------------------------------
